# %% [markdown]
# # Derivation of Lasso Regression (  L 1 )

# %% [markdown]
# ![WhatsApp Image 2024-10-15 at 01.45.32.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #  Different Cases of Lasso Regression

# %% [markdown]
# ![WhatsApp Image 2024-10-15 at 01.45.32 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-10-15 at 01.45.32 (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #  Why dont we get Sparcity when we use Ridge Regression but we get Sparcity when we use Lasso Regression

# %% [markdown]
# ![WhatsApp Image 2024-10-15 at 01.45.33.jpeg](data:image/jpeg;base64,...)
